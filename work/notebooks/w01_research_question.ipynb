# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHAMMADAFFAN786/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MUHAMMADAFFAN786/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane: Content Performance Optimization
#
# I chose the Content Performance Optimization lane because improving page performance can increase visibility, clicks, and user engagement. My goal is to identify which pages are most likely to benefit from optimization based on search performance metrics. This project can help prioritize SEO efforts using data instead of guesswork.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Research Question
#
# **Decision:** Identify which pages should be prioritized for SEO optimization.
#
# **Action:** Improve content quality, titles, metadata, and user engagement on the selected pages.
#
# **Cost of a Wrong Recommendation:** If low-potential pages are selected, time and SEO resources may be wasted while high-potential pages are ignored.
#
# **Why ML Can Help:** Machine learning can analyze multiple search performance metrics together and identify patterns that are difficult to detect manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains search performance metrics such as impressions, clicks, CTR, and average position. These metrics show that pages perform differently across search results, indicating opportunities to identify which pages should be prioritized for SEO improvements. This variation supports using data-driven methods to guide optimization decisions instead of relying only on manual judgment.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Careful Words
#
# This project provides decision support based on observed patterns in the available dataset. It does not prove causation or predict Google's ranking algorithm. The recommendations should be used to prioritize investigation and optimization rather than guarantee outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
